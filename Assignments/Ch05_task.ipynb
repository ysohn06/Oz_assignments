# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# ### Chapter05 : `Python 변수에 대한 개념 복습하기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```Python으로 변수를 생성하는 방법으로 올바른 것을 고르세요```
#
# 1. number == 20
# 2. 100 == number
# 3. number(7)
# 4. number = 7

# %% [markdown]
# **4번**
#
# 파이썬에서 변수는 **변수이름 = 값** 형태로 값을 할당하는 순간 자동으로 생성
# 변수 이름 규칙
# 1. 숫자로 시작 불가
# 2. -(hyphen) 사용 불가
# 3. 빈칸 대신 밑줄 사용
# 4. 대소문자 구분

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```다음 중 올바르지 않은 것을 골라주세요```
#
# 이름 = "김오즈"<br>
# 나이 = 14<br>
# 소속 = "마법중"<br>
# 등급 = 3<br>
#
# 1. 이름 + 소속
# 2. 나이 + 등급
# 3. 소속 + 등급

# %% [markdown]
# **3번**
#
# 소속: "마법중"은 문자열(str)이고 등급: 3은 정수(int)인데, 두 가지를 더하려고 했을 때 문자에 숫자를 더할 수 없다고 판단하기 때문에 *Type Error*가 일어난다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```아래 변수의 type으로 올바른것을 골라주세요```
#
# 퀴즈 = "스페인에서 카리나를 보고 하는 말은?"<br>
# type(퀴즈)

# %% [markdown]
# **str (문자열)**
#
# 파이썬에서 따옴표로 깜싸진 모든 텍스트는 문자열(string) 데이터 타입으로 분류한다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```다음 중 변수 이름으로 사용할 수 없는 것을 모두 골라주세요```
#
# 1. 78abc
# 2. ABC
# 3. _ABC
# 4. _hello%2
# 5. for

# %% [markdown]
# **1번, 4번, 5번**
#
# *   78abc : 변수 이름은 숫자로 시작할 수 없다.
# *   _hello%2 : 영문자, 숫자, 언더바(_)만 사용할 수 있으며 %, &, ! 같은 기호는 사용할 수 없다.
# *   for : 예약어(Reserved Words)를 사용할 수 없다. for, if, while, def 등 특정 기능을 수행하도록 미리 예약되어 있는 단어들은 변수로 사용할 수 없다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```다음 중 변수와 연산자의 사용 방법으로 올바르지 않은 것을 모두 골라주세요```
#
# x = 3
# y = 7
#
# 1. x = x + y
# 2. x // 2
# 3. z >< x
# 4. y += x
# 5. ++x

# %% [markdown]
# **3번, 5번**
#
# z><x : 크거나 작음을 비교하는 > 또는 <을 쓰거나 같음을 나타내기 위해서는 !=을 쓰지만, >< 라는 연산자는 존재하지 않는다.
#
# ++x : C, Java 등 다른 언어는 ++ 연산자를 지원하지만 파이썬에서는 지원하지 않는다. 값을 1 증가시키기 위해서는 x += 1 이라고 써야한다.

# %% [markdown]
# ----

# %% [markdown]
# ### Chapter06 : `Python 자료형인 int와 float 개념 복습하기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```실수를 정수로 만드는 식으로 올바른 것을 고르세요```
#
# 1. str(3.5)
# 2. int(3.5)
# 3. float(3.5)

# %% [markdown]
# **2번**
#
# *   str(3.5) : 실수를 문자열(string)으로 변환하여, 계산할 수 없는 형태인 "3.5"가 된다.
# *   float(3.5) : 실수를 그대로 실수(float)로 둬서 결과는 변함이 없다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```실수 3.5의 type과 동일한 것을 고르세요```
#
# 1. float(17//3)
# 2. int(10)-9
# 3. float11/2
# 4. float(10)-2

# %% [markdown]
# **4번**
#
#
# *   float(17//3)은 몫만 구하는 연산이므로 정수 5가 되며, 여기에 float를 씌우면 결과는 5.0이 된다.
# *   타입은 int(정수형)이므로 오답이다.
# *   float11/2 문장은 파이썬에서 에러가 발생한다. float와 11 사이에 괄호가 없거나 띄어쓰기가 잘못되었기 때문이다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```type(3.0 + 7.0)의 결과로 올바른 것을 고르세요```
#
# 1. 10
# 2. 10.0
# 3. int
# 4. float

# %% [markdown]
# **4번**
#
# 왜 "10.0"이 아니라 "float"?
#
# 문제에서 ""type(...)""이라는 함수로 감쌌기 때문에 데이터의 값이 얼마인지 묻는게 아니라, 데이터의 종류(타입)이 무엇인지 물어보는 함수이기 때문이다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```float(5)의 결과로 올바른 것을 고르세요```
#
# 1. 5
# 2. `<class float>`
# 3. 5.0
# 4. type error

# %% [markdown]
# **3번**
#
# float : 괄호 안에 있는 데이터를 실수(소수점이 있는 숫자)로 바꾸라는 명령어

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```int(13 / 2)의 결과로 올바른 것을 고르세요```
#
# 1. 6.5
# 2. 1
# 3. 6
# 4. 6.0

# %% [markdown]
# **3번**
#
# *   6.5 : int() 함수를 적용하기 전의 결과
# *   1 : 13 % 2 (나머지 연산)을 했을 때의 결과
# *   6.0 : int() 는 소수점을 남기지 않는다. 6.0은 여전히 실수 형태이다.

# %% [markdown]
# ----

# %% [markdown]
# ### Chapter07 : `Python 자료형인 str와 bool 개념 복습하기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```변수 퀴즈에 들어있는 정답 "어중이떠중이"를 출력하기 위한 슬라이싱으로 올바른 것을 모두 골라주세요```
#
# 퀴즈 = "스님이 공중에 뜬다를 4글자로 말하면? 어중이떠중이"
#
# 1. print(퀴즈[22:27])
# 2. print(퀴즈[22:])
# 3. print(퀴즈[22:28])
# 4. print(퀴즈[28])

# %% [markdown]
# **2번, 3번**
#
# 슬라이싱의 기본 원리
# 1. [시작 : 끝]
# 2. 글자 번호(인덱스) 세는 법 : 0부터 번호를 메기기 (공백과 문장 부호도 모두 한 칸씩 차지)
# 3. 끝번호를 비워두면 "시작부터 끝까지 전부다" 가져오라는 뜻

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```과일 변수에 들어있는 p의 개수를 구하는 코드로 올바른 것을 골라주세요```
#
# 과일 = "apple"
#
# 1. 과일.count('p')
# 2. count(과일, 'p')
# 3. 과일.index('p')
# 4. count('p')

# %% [markdown]
# **1번**
#
# 특정 문자가 몇개 들어있는지 셀 때 : 변수명.count('찾을 문자')

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ``` bool 타입에 해당하는 것만 골라주세요```
#
# 1. true
# 2. True
# 3. False
# 4. 0
# 5. 1

# %% [markdown]
# **2번, 3번**
#
# 파이썬에서 참과 거짓을 나타내는 bool(Boolean) 타입은 첫 글자가 대문자로 시작해야 한다는 엄격한 규칙을 가지고 있다.
#
# * 0, 1 : 0은 거짓, 1은 참의 의미를 갖기도 하지만 데이터 타입 자체는 int(정수)이다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```문자열의 길이를 구하는 방법으로 올바른 것을 고르세요```
#
# 라라랜드 =  "사람들은 다른 사람들의 열정에 끌리게 되어있어 자신이 잊은 걸 상기시켜 주니까"
#
# 1. 라라랜드.len()
# 2. length(라라랜드)
# 3. len(라라랜드)
# 4. count(라라랜드)

# %% [markdown]
# **3번**
#
# 문자열이나 리스트에서 전체의 길이를 구할 때 : len() 함수를 사용

# %% [markdown]
# ----

# %% [markdown]
# ### Chapter08 : `비교 연산자와 논리 연산자에 대해 복습해보기`

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```비교 연산자의 결과로 올바르지 않은 것을 골라주세요```
#
# 1. 8 == 2 * 4&emsp;&emsp;결과 : True
# 2. 4 != 2 + 2&emsp;&emsp;결과 : False
# 3. 2 * 3 is 3 + 3&emsp;&emsp;결과 : True
# 4. 8 is 4 * 2.0&emsp;&emsp;결과 : True
# 5. 5 is 6 - 1.1&emsp;&emsp;결과 : False

# %% [markdown]
# **4번**
#
# 4 * 2.0을 계산하면 결과는 8.0이 되므로, 이제 식은 8 is 8.0이 된다. 8은 정수(int)이고 8.0은 실수(float)인데, 파이썬에서 **is**는 "값이 같은가"가 아니라 "완전히 같은 객체인가"를 묻기 때문에 4번은 False가 나와야 한다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```"x는 5와 같지 않다"라는 뜻과 동일한 것을 골라주세요```
#
# 1. x <= 5
# 2. x != 5
# 3. x & 5
# 4. x ! 5

# %% [markdown]
# **2번**
#
# <= : 작거나 같다
# & : '비트 연산자'로 숫자를 2진수로 연산할 때 사용
# ! : 없는 형태의 연산자

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```비교 연산자와 논리 연산자의 결과로 올바른 것을 모두 골라주세요```
#
# x = 10
# y = 20
#
# 1. x == 10 or y == 10  결과 : False
# 2. x >= 10 and y < 30  결과 : True
# 3. not x == 10 결과 : False
# 4. y != 20 or x != 10  결과 : True
# 5. not y != 20 and x > 5  결과 : False

# %% [markdown]
# **2번, 3번**
#
# 오답 이유
# 1. x == 10 or y == 10 결과: False -> x == 10은 참(True)이고, y == 10은 거짓(False)인데 or 연산자는 둘 중 하나만 참이어도 전체를 True로 만든다.
#
# 2. y != 20 or x!= 10 결과: True -> y != 20(False)와 x != 10(False)를 or 연결했는데 둘 다 거짓이므로 결과는 False가 나와야 한다.
#
# 3. not y != 20 and x > 5 결과: False -> y != 20은 거짓(False)이지만 not이 붙어 참(True)로 변한다. 여기에 x > 5라는 참인 조건을 and로 연결했으니 결과는 True가 나와야 한다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```'치맥' and True의 결과로 올바른 것을 골라주세요```
#
# 1. False
# 2. 아묻따
# 3. True
# 4. 치맥True

# %% [markdown]
# **3번**
#
# *   파이썬에서 문자열의 bool값 : 데이터가 비어있지 않으면 참(True)로 간주
# *   and 연산자의 규칙 : 양쪽이 모두 참일때만 True를 결과로 내놓는다

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```논리 연산의 결과를 뒤집는 연산자를 골라주세요```
#
# 1. is not
# 2. not
# 3. !=
# 4. end
# 5. and
# 6. or

# %% [markdown]
# **2번**
